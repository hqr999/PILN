# %%
import urllib
from urllib import request
import re
import pandas as pd

# %%
url = "https://www.adorocinema.com/filmes/filme-215094/criticas/espectadores/?page="

# %%
def extrai_nome(html):
  inicio_nome = html[n].find('title="') + 7
  fim_nome = html[n].find('">\n<img')
  nome = html[n][inicio_nome:fim_nome]
  return nome

# %%
def extrai_infos(html):
  id = html[11:10+11]

  inicio_nome = html.find('title="') + 7
  fim_nome = html.find('">\n<img')
  nome = html[inicio_nome:fim_nome]

  inicio_nota = html.find('"stareval-note">') + 16
  fim_nota = html.find('</span></div>\n<span class="review-card-meta-date')
  nota = html[inicio_nota:fim_nota]

  inicio_data = html.find('date light">\n') + 14 + 10
  fim_data = html.find('\n</span>\n</div>\n</span>\n<div class="content-txt review-card')
  data = html[inicio_data:fim_data]

  inicio_texto = html.find('class="content-txt review-card-content">\n') + len('class="content-txt review-card-content">\n')
  fim_texto = html.find('\n</div>\n<div class="review-card-social"')
  texto = html[inicio_texto:fim_texto]
  
  return id, nome, nota, data, texto

# %%
# existem 12 páginas com comentários
qtd_pagina = 12
url_pagina = [url+str(x) for x in range(1, qtd_pagina+1)]
#print(url_pagina)

# %%
paginas_raw=[]
for x in url_pagina:
  try:
    response = request.urlopen(x)
    print("URL:",x,"OK")
    raw = response.read().decode('utf8')
    paginas_raw.append(raw)
  except urllib.error.HTTPError as e:
    print("Código erro: %d\nRazão do erro: %s" %(e.code, e.reason))
# Out:
# URL: https://www.adorocinema.com/filmes/filme-215094/criticas/espectadores/?page=1 OK
# URL: https://www.adorocinema.com/filmes/filme-215094/criticas/espectadores/?page=2 OK
# URL: https://www.adorocinema.com/filmes/filme-215094/criticas/espectadores/?page=3 OK
# URL: https://www.adorocinema.com/filmes/filme-215094/criticas/espectadores/?page=4 OK
# URL: https://www.adorocinema.com/filmes/filme-215094/criticas/espectadores/?page=5 OK
# URL: https://www.adorocinema.com/filmes/filme-215094/criticas/espectadores/?page=6 OK
# URL: https://www.adorocinema.com/filmes/filme-215094/criticas/espectadores/?page=7 OK
# URL: https://www.adorocinema.com/filmes/filme-215094/criticas/espectadores/?page=8 OK
# URL: https://www.adorocinema.com/filmes/filme-215094/criticas/espectadores/?page=9 OK
# URL: https://www.adorocinema.com/filmes/filme-215094/criticas/espectadores/?page=10 OK
# URL: https://www.adorocinema.com/filmes/filme-215094/criticas/espectadores/?page=11 OK
# URL: https://www.adorocinema.com/filmes/filme-215094/criticas/espectadores/?page=12 OK

# %%
tabela = []


for p in range(11):

  raw_reviews = []

  encontrar = 'id="review_'
  res = [i.start() for i in re.finditer(encontrar, paginas_raw[p])]
  print(res)
  #print(paginas_raw[0][res[0]:res[1]])


  for i in range(10):
      if i == 9:
          fim = -1
      else:
          fim = res[i+1]
      inicio = res[i]
      raw_review = paginas_raw[0][inicio:fim]
      raw_reviews.append(raw_review)


  for i in range(10):
    id, nome, nota, data, texto = extrai_infos(raw_reviews[i])
    dict = {'id': id, 'nome': nome, 'nota': nota, 'data': data, 'texto': texto}
    tabela.append(dict)
# Out:
# [120644, 123273, 127358, 130805, 133468, 135718, 137962, 140461, 143499, 146484]
# [120776, 123962, 127989, 130224, 132907, 135169, 138593, 141786, 147583, 157822]
# [120776, 123475, 126356, 128592, 130791, 133205, 135545, 138211, 140425, 142681]
# [120776, 123329, 126231, 128680, 131663, 134664, 137286, 139645, 142014, 144410]
# [120776, 123083, 125507, 128112, 130934, 133163, 136116, 140532, 143153, 146187]
# [120776, 123135, 125367, 129499, 131774, 134018, 136375, 139016, 141382, 143985]
# [120776, 123021, 125462, 129839, 132257, 134806, 137201, 139660, 142012, 144257]
# [120776, 123597, 126205, 128639, 130879, 133362, 136383, 139014, 141197, 143395]
# [120776, 123144, 125613, 128041, 130711, 133228, 135579, 138279, 140536, 142720]
# [120783, 125006, 127728, 130481, 132825, 135238, 137828, 140516, 142990, 145344]
# [120783, 123015, 125242, 127830, 130017, 132223, 134471, 138427, 140767, 142991]

# %%
df = pd.DataFrame(tabela)

# %%
display(df)
# Out:
#              id                                               nome  \
# 0    1001537281                                         FATOR - 20
# 1    1001517454                                              XL007
# 2    1001510038                                   An&iacute;sio P.
# 3    1001492623                                            Mauro A
# 4    1001487219                                           Hermes C
# ..          ...                                                ...
# 105  ass="stare                                           Hermes C
# 106  "review-ca                                   Matt Pines Grass
# 107  ="Nelson J                                         Alan David
# 108  AAAAAAAAAA  ABAIAAAAAAAAAAACH5BAEAAAAALAAAAAABAAEAAAICRAEA...
# 109  reviews" d                                           Vitor S.
#
#                                                   nota  \
# 0                                                  0,5
# 1                                                  0,5
# 2                                                  2,0
# 3                                                  2,0
# 4                                                  0,5
# ..                                                 ...
# 105                                                2,0
# 106                                                0,5
# 107                                                2,5
# 108                                                4,0
# 109  4,0</span></div>\n\n<span class="review-card-m...
#
#                        data                                              texto
# 0    24 de dezembro de 2019  Um filnal tão frio quanto o filme em si, além ...
# 1    22 de dezembro de 2019  Esse filme e essa trilogia, é uma piada de mal...
# 2    22 de dezembro de 2019  [TEM SPOILER]<br>Vou resumir, o filme é fraco,...
# 3    20 de dezembro de 2019  Eu não sei que 5 estrelas são estas que o públ...
# 4    20 de dezembro de 2019  Cópia da trilogia original, com uma pitada de ...
# ..                      ...                                                ...
# 105  20 de dezembro de 2019  Eu não sei que 5 estrelas são estas que o públ...
# 106  20 de dezembro de 2019  Cópia da trilogia original, com uma pitada de ...
# 107  22 de dezembro de 2019  Belos efeitos especiais e uma estória bem frac...
# 108  18 de dezembro de 2019  Star Wars: A Ascensão Skywalker é a celebração...
# 109  28 de dezembro de 2019  Esse Star wars foi sem nenhuma surpresa foi co...
#
# [110 rows x 5 columns]

# %%
#Colocar reviews de 3 para cima em uma pasta e de 2,5 para baixo em outra
#Duas classes:críticas positivas e negativas.
#Primeiro montar a classe das críticas positivas
if(nota>=3){
    #colocou os textos em um pastabde criticas positivas e faço um for para mudar a id de cada critica

}
# Out:
#   File "<ipython-input-15-aba3823d77c4>", line 3
#     if(dict{nota}>3){
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e2bdbb82-530b-4b71-85fb-c683a0c0911d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
